# %% [markdown]
# # Hi, Welcome

# %%
print("Hi, Welcome")

# %% [markdown]
# # Testing

# %% [markdown]
# ## Test create_circle_image

# %%
# Circle at custom position

import rsw_ai

rsw_ai.backend.create_circle_image.create_circle_image(
    filename="../outputs/dummy_circle.png",
    width=500,
    height=500,
    radius=50,
    circle_color=(123, 123, 123),
    background_color=(255, 255, 255),  # White
    center=(250, 100),
    thickness=5,
)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
import rsw_ai

if __name__ == "__main__":

    rsw_ai.backend.create_triangle_image.create_triangle_image(
        filename="../outputs/dummy_triangle_0.png",
        side_length=200,
        rotation=0,
    )

    rsw_ai.backend.create_triangle_image.create_triangle_image(
        filename="../outputs/dummy_triangle_45.png",
        side_length=200,
        rotation=45,
    )

    rsw_ai.backend.create_triangle_image.create_triangle_image(
        filename="../outputs/dummy_triangle_filled.png",
        side_length=200,
        rotation=30,
        triangle_color=(255, 0, 255),
        thickness=1,
    )
