# %% [markdown]
# # Hi, Welcome

# %%
print("Hi, Welcome")

# %% [markdown]
# # Testing

# %% [markdown]
# ## Test create_circle_image

# %%
# Circle at custom position

import rsw_ai

rsw_ai.backend.create_circle_image.create_circle_image(
    filename="../outputs/images/dummy_circle.png",
    width=300,
    height=300,
    radius=50,
    circle_color=(0, 0, 0),
    background_color=(255, 255, 255),  # White
    center=(150, 100),
    thickness=5,
)

print("done")

# %% [markdown]
# ## Test create_triangle_image

# %%
import rsw_ai.backend.create_triangle_image as aaa

if __name__ == "__main__":
    aaa.create_triangle_image(
        filename="../outputs/images/dummy_triangle_0.png",
        side_length=200,
        rotation=0,
    )

    aaa.create_triangle_image(
        filename="../outputs/images/dummy_triangle_45.png",
        side_length=200,
        rotation=45,
    )

    aaa.create_triangle_image(
        filename="../outputs/images/dummy_triangle_filled.png",
        side_length=200,
        rotation=30,
        triangle_color=(255, 0, 255),
        thickness=1,
    )

# %% [markdown]
# ## Test create_metadata_file

# %%
import rsw_ai.backend.create_metadata_file as backend

backend.create_metadata_file("../outputs/dummy_metadata.json", {"example": 123456})

# %% [markdown]
# ## Test create_circle_image_and_create_metadata_and_write_image_metadata_and_write_circle_metadata_and_create_metadata_file

# %%
# Create circle image and metadata

import rsw_ai.pipeline.create_circle_image_and_circle_metadata_file as pipeline

import rsw_ai.api.create_circle_dataset as api

pipeline.create_circle_image_and_create_circle_metadata_file(
    image_filename="../outputs/images/dummy_circle_pipeline.png",
    metadata_filename="../outputs/metadata/dummy_circle_pipeline.json",
    width=300,
    height=300,
    radius=50,
    circle_color=(0, 0, 0),
    background_color=(255, 255, 255),
    center=(150, 100),
    thickness=5,
)

api.create_circle_dataset(
    image_filename="../outputs/images/dummy_circle_api.png",
    metadata_filename="../outputs/metadata/dummy_circle_api.json",
    width=300,
    height=300,
    radius=150,
    circle_color=(0, 0, 0),
    background_color=(255, 255, 255),
    center=(150, 150),
    thickness=5,
)

print("done")
# Out:
# done
