# %% [markdown]
# # Hi, Welcome

# %%
print("Hi, Welcome")

# %% [markdown]
# # Testing

# %% [markdown]
# ## Test create_circle_image

# %%
# Circle at custom position

import rsw_ai

rsw_ai.backend.create_circle_image.create_circle_image(
    filename="../outputs/images/dummy_circle.png",
    width=300,
    height=300,
    radius=50,
    circle_color=(0, 0, 0),
    background_color=(255, 255, 255),  # White
    center=(150, 100),
    thickness=5,
)

print("done")

# %% [markdown]
# ## Test create_triangle_image

# %%
import rsw_ai

if __name__ == "__main__":

    rsw_ai.backend.create_triangle_image.create_triangle_image(
        filename="../outputs/images/dummy_triangle_0.png",
        side_length=200,
        rotation=0,
    )

    rsw_ai.backend.create_triangle_image.create_triangle_image(
        filename="../outputs/images/dummy_triangle_45.png",
        side_length=200,
        rotation=45,
    )

    rsw_ai.backend.create_triangle_image.create_triangle_image(
        filename="../outputs/images/dummy_triangle_filled.png",
        side_length=200,
        rotation=30,
        triangle_color=(255, 0, 255),
        thickness=1,
    )

# %% [markdown]
# ## Test create_circle_image_and_create_circle_metadata_and_create_metadata_file

# %%
# Create circle image and metadata

import rsw_ai

rsw_ai.pipeline.create_circle_image_and_create_circle_metadata_and_create_metadata_file.create_circle_image_and_create_circle_metadata_and_create_metadata_file(
    filename="../outputs/images/dummy_circle.png",
    json_filename="../outputs/metadata/dummy_circle.json",
    width=300,
    height=300,
    radius=50,
    circle_color=(0, 0, 0),
    background_color=(255, 255, 255),
    center=(150, 100),
    thickness=5,
)

print("done")
# Out:
# done

# %%
import torch
print(torch)
# Out:
# <module 'torch' from 'c:\\Users\\vsgm0\\anaconda3\\envs\\rsw_ai\\Lib\\site-packages\\torch\\__init__.py'>
