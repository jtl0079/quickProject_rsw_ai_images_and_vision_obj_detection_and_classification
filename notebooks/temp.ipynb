# %%
from rsw_ai.backend.create_metadata_file import create_metadata_file   # 假设函数在这个文件里

# test
data = {
    "shape": "circle",
    "radius": 50,
    "color": [255, 0, 0]
}

create_metadata_file("circle.json", data)

# %%
import rsw_ai

print(rsw_ai)
print(rsw_ai.pipeline)
# Out:
# <module 'rsw_ai' from 'C:\\Users\\vsgm0\\Downloads\\AI\\temp\\quickProject_rsw_ai_images_and_vision_obj_detection_and_classification\\src\\rsw_ai\\__init__.py'>
# <module 'rsw_ai.pipeline' from 'C:\\Users\\vsgm0\\Downloads\\AI\\temp\\quickProject_rsw_ai_images_and_vision_obj_detection_and_classification\\src\\rsw_ai\\pipeline\\__init__.py'>
