# %% [markdown]
# # Hi, Welcome

# %%
print("Hi, Welcome")

# %% [markdown]
# # Testing

# %% [markdown]
# ## Test create_circle_image

# %%
# Circle at custom position

import rsw_ai
rsw_ai.backend.create_circle_image.create_circle_image(
    filename="../outputs/circle.png",
    width=1000,
    height=1000,
    radius=50,
    circle_color=(0, 123, 234),
    background_color=(255, 255, 255),  # White
    center=(100, 200),
    thickness=5,

)

# %%
# Out:
# hi
