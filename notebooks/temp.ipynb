# %%
# Out:
# <module 'rsw_ai' from 'C:\\Users\\vsgm0\\Downloads\\AI\\temp\\quickProject_rsw_ai_images_and_vision_obj_detection_and_classification\\src\\rsw_ai\\__init__.py'>

# %%
from rsw_ai.model.DatasetGenerator import DatasetGenerator
import random
generator = DatasetGenerator()

generator.create_circle_dataset(
    image_filename="../outputs/images/circle.png",
    metadata_filename="../outputs/metadata/circle.json",
    count= 10,
    center= lambda param_a:(
        random.randint(0,499),
        random.randint(0,499)
    ),
    radius= 50,
    thickness=10,
)

# %%
from rsw_ai.enum.ObjectClass import ObjectClass

ObjectClass.from_label("square").id
# Out:
# 2

# %%
from rsw_ai.backend.read_metadata_file import read_metadata_file

read_metadata_file("../outputs/metadata/dummy_circle_api.json")
# Out:
# {'image': {'filename': '../outputs/images/dummy_circle_api.png',
#   'width': 300,
#   'height': 300},
#  'objects': [{'id': 0,
#    'class': 'circle',
#    'center': [150, 150],
#    'bbox': {'xmin': 0, 'ymin': 0, 'xmax': 300, 'ymax': 300},
#    'width': 300,
#    'height': 300,
#    'rotation': 0.0,
#    'color': [0, 0, 0],
#    'filled': False,
#    'radius': 150}]}
